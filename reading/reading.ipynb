# %%
import numpy as np
import os, platform
import winsound
import sys
import keras
import keras.backend as k
from keras.layers import Conv2D,MaxPooling2D,SpatialDropout2D,Flatten,Dropout,Dense
from keras.models import Sequential,load_model
from keras.optimizers import adam
from keras.preprocessing import image
import cv2
import datetime
# Out:
# Using TensorFlow backend.

# %%
model=Sequential()


model.add(Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)))
model.add(MaxPooling2D() )
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D() )
model.add(Conv2D(32,(3,3),activation='relu'))
model.add(MaxPooling2D() )
model.add(Flatten())
model.add(Dense(100,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

model.summary()

from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

training_set = train_datagen.flow_from_directory(
        'D:\\find face\\of500_images\\of500_images\\reading\\train',
        target_size=(150,150),
        batch_size=16 ,
    #    color_mode="grayscale",   
        class_mode='binary')

test_set = test_datagen.flow_from_directory(
        'D:\\find face\\of500_images\\of500_images\\reading\\test',
        target_size=(150,150),
        batch_size=16,
    #    color_mode="grayscale",  
        class_mode='binary')

model_saved=model.fit_generator(
        generator=training_set,
        epochs=10,
        validation_data=test_set,

        )

model.save('action_clap.h5',model_saved)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 9248)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               924900
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# =================================================================
# Total params: 944,393
# Trainable params: 944,393
# Non-trainable params: 0
# _________________________________________________________________
# Found 227 images belonging to 1 classes.
# Found 56 images belonging to 1 classes.
# Epoch 1/10
# 15/15 [==============================] - 10s 694ms/step - loss: 0.0671 - accuracy: 0.9295 - val_loss: 3.8802e-23 - val_accuracy: 1.0000
# Epoch 2/10
# 15/15 [==============================] - 11s 734ms/step - loss: 9.2388e-12 - accuracy: 1.0000 - val_loss: 1.9895e-36 - val_accuracy: 1.0000
# Epoch 3/10
# 15/15 [==============================] - 11s 749ms/step - loss: 1.6424e-19 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 4/10
# 15/15 [==============================] - 11s 746ms/step - loss: 4.0893e-18 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 5/10
# 15/15 [==============================] - 11s 745ms/step - loss: 2.5871e-19 - accuracy: 1.0000 - val_loss: 2.8283e-34 - val_accuracy: 1.0000
# Epoch 6/10
# 15/15 [==============================] - 10s 699ms/step - loss: 1.9053e-19 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 7/10
# 15/15 [==============================] - 11s 701ms/step - loss: 2.4515e-19 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 8/10
# 15/15 [==============================] - 11s 720ms/step - loss: 2.7176e-18 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000
# Epoch 9/10
# 15/15 [==============================] - 11s 732ms/step - loss: 2.8401e-19 - accuracy: 1.0000 - val_loss: 2.4510e-34 - val_accuracy: 1.0000
# Epoch 10/10
# 15/15 [==============================] - 12s 783ms/step - loss: 3.4297e-19 - accuracy: 1.0000 - val_loss: 0.0000e+00 - val_accuracy: 1.0000

# %%
cap=cv2.VideoCapture(0)
face_cascade=cv2.CascadeClassifier('D:\\DIP PROJECT\\FaceMaskDetector-master\\haarcascade_frontalface_default.xml')
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
os_name=platform.system()
while cap.isOpened():
    _,img=cap.read()
    face=face_cascade.detectMultiScale(img,scaleFactor=1.1,minNeighbors=4)
    for(x,y,w,h) in face:
        face_img = img[y:y+h, x:x+w]
        cv2.imwrite('temp.jpg',face_img)
        test_image=image.load_img('temp.jpg',target_size=(150,150,3))
        test_image=image.img_to_array(test_image)
        test_image=np.expand_dims(test_image,axis=0)
        pred=model.predict_classes(test_image)[0][0]
        
        if pred==1:
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),3)
            cv2.putText(img,'NOT READING',((x+w)//2,y+h+20),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),3)
            if (os_name=='Windows'):  #For Windows Operating System
                winsound.Beep(frequency, duration)
                
            elif (os_name=='Darwin'): #For MAC Operating System
                os.system('Say "Mask Not Detected"')
                sys.stdout.write('\a')
                sys.stdout.flush()
            cv2.putText(img,"NOT READING",(400,450),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),1)
        else:
            cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),3)
            cv2.putText(img,'READING',((x+w)//2,y+h+20),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),3)
            cv2.putText(img,"",(400,450),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),1)
       # datet=str(datetime.datetime.now())
      #  cv2.putText(img,datet,(400,450),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),1)
          
    cv2.imshow('img',img)
    
    if cv2.waitKey(1)==ord('q'):   
        break
    
cap.release()
cv2.destroyAllWindows()
cv2.VideoCapture.release(cap)
